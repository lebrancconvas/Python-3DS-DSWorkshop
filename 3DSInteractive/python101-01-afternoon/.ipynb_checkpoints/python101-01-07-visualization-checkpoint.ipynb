# %% [markdown]
# <h1><center> Machine Learning for Young Data Scientist with Python </center><h1/>
# <h3><center> "VISUALIZATION" </center><h3/>
#
#
# <img src="images/courses.png">

# %% [markdown]
# ## 7.1 Basic plots

# %%
import numpy as np
import matplotlib.pyplot as plt
# inline plot (for jupyter)
# %matplotlib inline

# %%
x = np.linspace(0, 10, 50)
sinus = np.sin(x)
plt.plot(x, sinus)
plt.title('My First Plot')
plt.xlabel('this is x!')
plt.ylabel('this is y!')
# Out:
# Text(0,0.5,'this is y!')

# %%
plt.plot(x,sinus, 'go--', linewidth=2, markersize=5)
plt.title('My First Plot')
plt.xlabel('this is x!')
plt.ylabel('this is y!')
# Out:
# Text(0,0.5,'this is y!')

# %%
plt.plot(x, sinus, "o")
plt.show()

# %%
# Rapid multiplot
cosinus = np.cos(x)
plt.plot(x, sinus, "-b", x, sinus, "ob", x, cosinus, "-r", x, cosinus, "or")
plt.xlabel('this is x!')
plt.ylabel('this is y!')
plt.title('My First Plot')
plt.show()

# %%
# Step by step
plt.plot(x, sinus, label='sinus', color='blue', linestyle='--', linewidth=2)
plt.plot(x, cosinus, label='cosinus', color='red', linestyle='-', linewidth=2)
plt.xlabel('this is x!')
plt.ylabel('this is y!')
plt.title('My First Plot')
plt.legend()
plt.show()

# %% [markdown]
# ## 7.2 Scatter (2D) plots

# %%
import pandas as pd

# %%
path = 'input-data/salary_table.csv'
salary = pd.read_csv(path)
df = salary

# %%
df.head()
# Out:
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
df.shape
# Out:
# (46, 4)

# %% [markdown]
# ### 7.2.1 Simple scatter with colors

# %%
colors = {'Bachelor':'r', 'Master':'g', 'Ph.D':'blue'}

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['experience'], df['salary'], c=df['education'].apply(lambda x: colors[x]), s=100)
plt.xlabel('Year Experiences')
plt.ylabel('Salary')
plt.title('Salary vs Year')
# Out:
# Text(0.5,1,'Salary vs Year')

# %% [markdown]
# ### 7.2.2 Scatter plot with colors and symbols

# %%
## Define colors / sumbols manually
symbols_manag = dict(Y='*', N='.')
colors_edu = {'Bachelor':'r', 'Master':'g', 'Ph.D':'blue'}

# %%
## Figure size
plt.figure(figsize=(10,8))

## group by education x management => 6 groups
for values, d in salary.groupby(['education','management']):
    edu, manager = values
    plt.scatter(d['experience'], d['salary'], marker=symbols_manag[manager],color=colors_edu[edu],s=150, label=manager+"/"+edu)
## Set labels
plt.xlabel('Experience') 
plt.ylabel('Salary') 
plt.title('Salary vs Year')
plt.legend(loc=4) # lower right 
plt.show()

# %%
for values, d in salary.groupby(['education','management']):
    print(values, d)
# Out:
# ('Bachelor', 'N')     salary  experience education management
# 7    10535           2  Bachelor          N
# 13   11417           4  Bachelor          N
# 20   12336           6  Bachelor          N
# 28   13548           8  Bachelor          N
# 29   14467          10  Bachelor          N
# 34   14861          11  Bachelor          N
# 37   15990          13  Bachelor          N
# 43   17483          16  Bachelor          N
# 45   19346          20  Bachelor          N
# ('Bachelor', 'Y')     salary  experience education management
# 0    13876           1  Bachelor          Y
# 10   14975           3  Bachelor          Y
# 19   15965           5  Bachelor          Y
# 24   16978           7  Bachelor          Y
# 26   17404           8  Bachelor          Y
# ('Master', 'N')     salary  experience education management
# 3    11283           1    Master          N
# 6    11772           2    Master          N
# 9    12313           3    Master          N
# 16   12884           4    Master          N
# 17   13245           5    Master          N
# 22   13839           6    Master          N
# 25   14803           8    Master          N
# 30   15942          10    Master          N
# 35   16882          12    Master          N
# 39   17949          14    Master          N
# 42   18838          16    Master          N
# 44   19207          17    Master          N
# ('Master', 'Y')     salary  experience education management
# 5    20872           2    Master          Y
# 11   21371           3    Master          Y
# 23   22884           6    Master          Y
# 32   23780          10    Master          Y
# 33   25410          11    Master          Y
# 38   26330          13    Master          Y
# 41   27837          16    Master          Y
# ('Ph.D', 'N')     salary  experience education management
# 1    11608           1      Ph.D          N
# 4    11767           1      Ph.D          N
# 8    12195           2      Ph.D          N
# 15   13231           4      Ph.D          N
# 18   13677           5      Ph.D          N
# ('Ph.D', 'Y')     salary  experience education management
# 2    18701           1      Ph.D          Y
# 12   19800           3      Ph.D          Y
# 14   20263           4      Ph.D          Y
# 21   21352           6      Ph.D          Y
# 27   22184           8      Ph.D          Y
# 31   23174          10      Ph.D          Y
# 36   24170          12      Ph.D          Y
# 40   25685          15      Ph.D          Y

# %% [markdown]
# ## 7.3 Saving Figures

# %%
### bitmap format
plt.plot(x, sinus)
plt.savefig("output-data/sinus.png")
plt.close()

# %%
# Prefer vectorial format (SVG: Scalable Vector Graphics) can be edited with # Inkscape, Adobe Illustrator, Blender, etc.
plt.plot(x, sinus)
plt.savefig("output-data/sinus.svg")
plt.close()

# %%
# Or pdf
plt.plot(x, sinus)
plt.savefig("output-data/sinus.pdf")
plt.close()
