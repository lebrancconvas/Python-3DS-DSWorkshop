# %% [markdown]
# <h1><center> Machine Learning for Young Data Scientist with Python </center><h1/>
# <h3><center> "READ DATA FROM TWITTER" </center><h3/>
#
#
# <img src="images/courses.png">

# %% [markdown]
# ## Automate file download in Python

# %%
import tweepy

# %%
access_token = "808869773249384448-eq2ffryjCiSvWb9EG63eFvwlf9cPFnz"
access_token_secret = "5sELYS8FSRDxgNxPR9PJk2DykQ48pU4oyoIzTcdvXkmJL"
consumer_key = "l6dlHIFHK3un2jG9KcRGlNQSq"
consumer_secret = "0KYTsuOwAFoh1HiI6J0EtpfdcSAkf1KVrZQzToYqMZgnsrnQNP"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
#override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):
    def on_status(self, status):
        print(status.text)

# %%
# Initialize Stream listener
l = MyStreamListener()

# %%
# Create you Stream object with authentication
stream = tweepy.Stream(auth, l)

# %%
# Filter Twitter Streams to capture data by the keywords:
tweets = stream.filter(track=['got7'], async=True)

# %%
print(tweets)
# Out:
# None
# RT @LING2303: 聽晚係咩？？？
# GOT7 3rd Album &lt;Present : YOU&gt;
# UNIT TEASER
# #JACKSON #BAMBAM
#
# 2018.09.17 MON 6PM
#
# #GOT7
# #갓세븐
# #PresentYOU
# #Lullaby
# #g…
# RT @02950424: Pls RT #GOT7 - #PRESENTYOU + BENEFITS + POSTER
# รอบแรกของแถมของครบ
#
# 🛒ราคา  720 รวมภาษี
# 📦ค่าส่ง 100 / 130
# 💳มัดจำได้อัลบั้มละ…
# RT @JJDAILY_: #GOT7 took the 4 crown for Mwave’s “K-Pop Idol Group Stan” since April!! WHAT A KING!!
# @GOT7Official https://t.co/Ebd6qqMeZ5
# RT @GOT7Official: GOT7 3rd Album &lt;Present : YOU&gt;
# ALBUM PREVIEW
#
# 2018.09.17 MON 6PM
#
# #GOT7
# #갓세븐
# #PresentYOU
# #Lullaby https://t.co/mzCJQVuBtO
# RT @apple_5840: [Trans] Dr Belmeur’s Weibo: “Tmr is our GOT7’s Mark’s 24th birthday. Dr Belmeur wishes Mark a happy birthday, hope that all…
# RT @Poompuii3: เปิดพรี บั้มบ้านเจบีบาร์
# 👉บั้มล่ะ 750 รวมของแถม
# 👉มัดจำ 500 ต่อบั้ม
# *รับแค่วันนี้ถึง 5 โมงเย็น*
# รายละเอียด ของแถม
# 👇
# สนใจ DM
# #…
# RT @GOT7Official: GOT7 3rd Album &lt;Present : YOU&gt;
# ...

# %%
stream.disconnect()
# Out:
# บั้มเปล่า160 เทรดดิ้ง โปสการ์ด ฟตก ราคารวมส่งแล้วค่ะ สนใจdm
# #GOT7
# #갓세븐 #PresentYOU #ขายของสะสมgot7 #ขายการ์ดgot7… https://t.co/CLIy09oRBK

# %%
print(tweets)
# Out:
# None
