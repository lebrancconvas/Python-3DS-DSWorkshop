# %% [markdown]
# <h1><center> Machine Learning for Young Data Scientist with Python </center><h1/>
# <h3><center> "READ DATA FROM WEBSITE" </center><h3/>
#
#
# <img src="images/courses.png">

# %% [markdown]
# ## Automate file download in Python

# %%
from urllib.request import urlretrieve

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'

# %%
urlretrieve(url, 'download-data/winequality-white.csv')
# Out:
# ('download-data/winequality-white.csv',
#  <http.client.HTTPMessage at 0x108295550>)

# %% [markdown]
# ## GET requests using requests

# %%
import requests

# %%
r = requests.get(url)

# %%
url = "https://en.wikipedia.org/wiki/BNK48"

# %%
r = requests.get(url)

# %%
text = r.text

# %%
text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>BNK48 - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"BNK48","wgTitle":"BNK48","wgCurRevisionId":857799706,"wgRevisionId":857799706,"wgArticleId":53223027,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Thai-language sources (th)","CS1 Japanese-language sources (ja)","Use dmy dates from February 2017","Official website different in Wikidata and Wikipedia","Articles with hCards","Articles containing potentially dated statements from August 2018","All articles containing potentially dated statements","Articles containing Thai-language
# ...

# %% [markdown]
# ## Scraping the web in Python

# %%
from bs4 import BeautifulSoup
import requests

# %%
soup = BeautifulSoup(text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>BNK48 - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %% [markdown]
# ## Print in a pretty way

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    BNK48 - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %% [markdown]
# ## Get Text From Website

# %%
print(soup.title)
# Out:
# <title>BNK48 - Wikipedia</title>

# %%
print(soup.title.name)
# Out:
# title

# %%
print(soup.title.string)
# Out:
# BNK48 - Wikipedia

# %%
print(soup.get_text())
# Out:
# BNK48 - Wikipedia
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
# ...

# %% [markdown]
# ## Exploring BeautifulSoup

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# None
# #mw-head
# #p-search
# /wiki/File:BNK48_Cat_Expo_2017.jpg
# /wiki/Bangkok
# /wiki/Thailand
# /wiki/Thai_pop_music
# /wiki/J-pop
# /wiki/Pop_music
# #cite_note-thansettaki-1
# /wiki/AKB48_Group
# http://www.bnk48.com
# /wiki/List_of_BNK48_members
# /wiki/List_of_BNK48_members#Former_members
# /wiki/Teen_idol
# /wiki/Musical_ensemble
# /wiki/Japan
# /wiki/AKB48
# /wiki/Indonesia
# /wiki/JKT48
# /wiki/Yak_Cha_Dai_Phop_Thoe
# /wiki/Khukki_Siangthai
# #cite_note-2
# //en.wikipedia.org/w/index.php?title=BNK48&action=edit
# /wiki/Bangkok
# /wiki/Thailand
# /wiki/Orchid_(color)
# #cite_note-3
# #History
# #2016
# #2017
# #2018
# #Members
# #Management
# #Managing_entities
# #Financing
# #Contracts
# #Criticism
# #Promotion
# #Shows_and_events
# #Theatre
# #Image
# #Philanthropy
# #Discography
# #Filmography
# #Honours
# #Awards
# #References
# #Further_reading
# #External_links
# /w/index.php?title=BNK48&action=edit&section=1
# /w/index.php?title=BNK48&action=edit&section=2
# ...
